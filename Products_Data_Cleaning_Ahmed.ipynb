# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'products.csv')

# %%
#check the null values
print(df.isnull().sum() )
# Out:
# Product_ID          0
# Product_Name        0
# Product_Category    0
# Product_Cost        0
# Product_Price       0
# dtype: int64

# %%
#check for the duplicate values
df.nunique()
# Out:
# Product_ID          35
# Product_Name        35
# Product_Category     5
# Product_Cost        16
# Product_Price       18
# dtype: int64

# %%
#remove the the $ from both product_cost & product_price
df["Product_Cost"] = df["Product_Cost"].str.replace("$", "", regex=False).astype(float)
df["Product_Price"] = df["Product_Price"].str.replace("$", "", regex=False).astype(float)
